# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
df=pd.read_json('../../03_DataPreprocessing/00_Merge/Merged.json')
df2=pd.read_json('../../04_DataMining/01_Preprocessing/First.json')

# %%
df.head()
# Out:
#       country     degree       eng  engExamResult           field  fieldGroup  \
# 10     canada  Doctorate      High       7.500000        electric        11.0
# 100    sweden    Masters  VeryHigh       8.000000  urban planning         NaN
# 1002  germany    Masters      High       7.153244         physics         2.0
# 1003   canada    Masters  VeryHigh       8.000000        electric        11.0
# 1006   sweden    Masters  VeryHigh       8.000000             law         5.0
#
#        fund fundType  fundValue  gpaBachelors  ...   papersGLOB papersIRAN  \
# 10     True    Award      25348           3.0  ...           11          1
# 100   False      n/a          0           2.5  ...            0          0
# 1002  False      n/a          0           2.0  ...            0          0
# 1003   True    Award      28400           4.0  ...            1          0
# 1006  False      n/a          0           4.0  ...            0          0
#
# ...

# %%
df2['uniBachelors']=df['uniBachelors']
df2['uniMasters']=df['uniMasters']
df2['paper']=df2.papersGLOB+(df2.papersIRAN*0.25)
del df2['papersGLOB']
del df2['papersIRAN']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-da96c7d6edf4> in <module>()
# ----> 1 df2['uniBachelors']=df['uniBachelors']
#       2 df2['uniMasters']=df['uniMasters']
#       3 df2['paper']=df2.papersGLOB+(df2.papersIRAN*0.25)
#       4 del df2['papersGLOB']
#       5 del df2['papersIRAN']
#
# NameError: name 'df' is not defined

# %%
df2.head()
# Out:
#       country  countryCoded     degree  degreeCoded       eng  engCoded  \
# 10     canada             1  Doctorate            1      High         1
# 100    sweden             2    Masters            0  VeryHigh         0
# 1002  germany             3    Masters            0      High         1
# 1003   canada             1    Masters            0  VeryHigh         0
# 1006   sweden             2    Masters            0  VeryHigh         0
#
#       fieldGroup   fund  gpaBachelors  gpaMasters    gre highLevelBachUni  \
# 10            11   True           3.0    4.000000   True             True
# 100            0  False           2.5    3.442986   True             True
# 1002           2  False           2.0    3.442986  False             True
# 1003          11   True           4.0    3.442986   True             True
# 1006           5  False           4.0    3.442986  False             True
#
#      highLevelMasterUni              targetUni                 uniAccepted  \
# ...

# %%
df2.head()
# Out:
#       country  countryCoded     degree  degreeCoded       eng  engCoded  \
# 10     canada             1  Doctorate            1      High         1
# 100    sweden             2    Masters            0  VeryHigh         0
# 1002  germany             3    Masters            0      High         1
# 1003   canada             1    Masters            0  VeryHigh         0
# 1006   sweden             2    Masters            0  VeryHigh         0
#
#       fieldGroup   fund  gpaBachelors  gpaMasters    gre highLevelBachUni  \
# 10            11   True           3.0    4.000000   True             True
# 100            0  False           2.5    3.442986   True             True
# 1002           2  False           2.0    3.442986  False             True
# 1003          11   True           4.0    3.442986   True             True
# 1006           5  False           4.0    3.442986  False             True
#
#      highLevelMasterUni              targetUni                 uniAccepted  \
# ...

# %%
df2.to_json('First.json',date_format='utf8')
