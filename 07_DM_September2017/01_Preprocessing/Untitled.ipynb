# %%
import numpy as np
from pandas import Series, DataFrame
import pandas as pd

# %%
df=pd.read_json('./First.json').sort_index()

# %%
df.head(2)
# Out:
#           country  countryCoded     degree  degreeCoded       eng  engCoded  \
# 2  united kingdom             4  Doctorate            1      High         1
# 3   united states             0  Doctorate            1  VeryHigh         0
#
#    fieldGroup  fund  gpaBachelors  gpaMasters    gre highLevelBachUni  \
# 2           7  TRUE           3.5    3.442986  FALSE            FALSE
# 3           5  TRUE           2.5    3.500000   TRUE             TRUE
#
#   highLevelMasterUni      paper     targetUni  uniRank  year
# 2              FALSE   6.666667   heriot-watt    692.0  2007
# 3              FALSE  11.333333  northwestern     20.0  2010

# %%
for d in df[df.country=='canada'].index:
    df.loc[d,'countryCoded']=0
for d in df[df.country==u'switzerland'].index:
    df.loc[d,'countryCoded']=1

# %%
df[df.country==u'canada']
# Out:
#      country  countryCoded     degree  degreeCoded       eng  engCoded  \
# 10    canada             0  Doctorate            1      High         1
# 13    canada             0  Doctorate            1  VeryHigh         0
# 16    canada             0  Doctorate            1      High         1
# 17    canada             0  Doctorate            1      High         1
# 18    canada             0    Masters            0      High         1
# 24    canada             0    Masters            0    Medium         2
# 34    canada             0  Doctorate            1  VeryHigh         0
# 40    canada             0  Doctorate            1  VeryHigh         0
# 47    canada             0  Doctorate            1      High         1
# 48    canada             0    Masters            0      High         1
# 49    canada             0    Masters            0      High         1
# 53    canada             0    Masters            0  VeryHigh         0
# ...

# %%
df.head(10)
# Out:
#            country  countryCoded     degree  degreeCoded       eng  engCoded  \
# 2   united kingdom             4  Doctorate            1      High         1
# 3    united states             0  Doctorate            1  VeryHigh         0
# 5    united states             0  Doctorate            1  VeryHigh         0
# 6           sweden             2    Masters            0      High         1
# 7            spain             3    Masters            0  VeryHigh         0
# 8        australia             1    Masters            0    Medium         2
# 9    united states             0    Masters            0  VeryHigh         0
# 10          canada             0  Doctorate            1      High         1
# 12   united states             0    Masters            0      High         1
# 13          canada             0  Doctorate            1  VeryHigh         0
#
#     fieldGroup   fund  gpaBachelors  gpaMasters    gre highLevelBachUni  \
# ...

# %%
df.to_json('First.json',date_format='utf8')
