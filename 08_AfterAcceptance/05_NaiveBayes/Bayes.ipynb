# %%
import numpy as np
from pandas import Series, DataFrame
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import scale
import matplotlib.pylab as plt

# %%
olddf=pd.read_json('../01_Preprocessing//Second.json').sort_index()

# %%
olddf.head(2)
# Out:
#           country  countryCode     degree  degreeCode  eng  \
# 2  united kingdom            4  Doctorate           1  8.0
# 3   united states            0  Doctorate           1  8.0
#
#                    field fieldG_0 fieldG_1 fieldG_10 fieldG_11  ...    greQ  \
# 2  petroleum engineering    False    False     False     False  ...     NaN
# 3                  civil    False    False     False     False  ...   159.0
#
#     greV greW highBU highMU paper                     rejUni     targetUni  \
# 2    NaN  NaN  False  False     7                        n/a   heriot-watt
# 3  143.0  3.0   True  False    11  UC Berkeley, Georgia Tech  northwestern
#
#   uniRank  year
# 2   692.0  2007
# 3    20.0  2010
#
# [2 rows x 41 columns]

# %%
# olddf.targetUni.replace('n/a',np.nan,inplace=True)

# %%
olddf.columns
# Out:
# Index([u'country', u'countryCode', u'degree', u'degreeCode', u'eng', u'field',
#        u'fieldG_0', u'fieldG_1', u'fieldG_10', u'fieldG_11', u'fieldG_12',
#        u'fieldG_13', u'fieldG_14', u'fieldG_15', u'fieldG_16', u'fieldG_17',
#        u'fieldG_18', u'fieldG_2', u'fieldG_3', u'fieldG_4', u'fieldG_5',
#        u'fieldG_6', u'fieldG_7', u'fieldG_8', u'fieldG_9', u'fieldGroup',
#        u'fund', u'fundValue', u'gpaB', u'gpaM', u'gre', u'greQ', u'greV',
#        u'greW', u'highBU', u'highMU', u'paper', u'rejUni', u'targetUni',
#        u'uniRank', u'year'],
#       dtype='object')

# %%
#Master

# %%
df=olddf[['countryCode','degreeCode','eng',
      'fieldG_0','fieldG_1','fieldG_10','fieldG_11','fieldG_12',
      'fieldG_13','fieldG_14','fieldG_15','fieldG_16','fieldG_17',
      'fieldG_18','fieldG_2','fieldG_3','fieldG_4','fieldG_5',
      'fieldG_6','fieldG_7','fieldG_8','fieldG_9',
      'gpaB','gre','highBU','paper','uniRank','year']]
# 'greQ','greV','greW',

# %%
df.head(2)
# Out:
#    countryCode  degreeCode  eng fieldG_0 fieldG_1 fieldG_10 fieldG_11  \
# 2            4           1  8.0    False    False     False     False
# 3            0           1  8.0    False    False     False     False
#
#   fieldG_12 fieldG_13 fieldG_14  ...  fieldG_6 fieldG_7 fieldG_8 fieldG_9  \
# 2     False     False     False  ...     False     True    False    False
# 3     False     False     False  ...     False    False    False    False
#
#   gpaB    gre highBU paper uniRank  year
# 2  3.5  False  False     7   692.0  2007
# 3  2.5   True   True    11    20.0  2010
#
# [2 rows x 28 columns]

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(df.countryCode.values)
xdf = pd.DataFrame(x_scaled)
xdf
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\sklearn\preprocessing\data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# C:\ProgramData\Anaconda2\lib\site-packages\sklearn\preprocessing\data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
#              0
# 0     0.571429
# 1     0.000000
# 2     0.000000
# 3     0.285714
# 4     0.428571
# 5     0.142857
# 6     0.000000
# 7     0.000000
# 8     0.000000
# 9     0.000000
# 10    0.000000
# 11    0.000000
# 12    0.000000
# ...

# %%
df.ix[2]
# Out:
# countryCode        4
# degreeCode         1
# eng                8
# fieldG_0       False
# fieldG_1       False
# fieldG_10      False
# fieldG_11      False
# fieldG_12      False
# fieldG_13      False
# fieldG_14      False
# fieldG_15      False
# fieldG_16      False
# fieldG_17      False
# fieldG_18      False
# fieldG_2       False
# fieldG_3       False
# fieldG_4       False
# fieldG_5       False
# fieldG_6       False
# fieldG_7        True
# fieldG_8       False
# fieldG_9       False
# gpaB             3.5
# gre            False
# highBU         False
# paper              7
# uniRank          692
# year            2007
# Name: 2, dtype: object

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(df, olddf.fund)
y_pred = gnb.predict(df)
print("Number of mislabeled points out of a total %d points : %d"
      % (df.shape[0],(olddf.fund != y_pred).sum()))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-fe256bfb6349> in <module>()
#       1 from sklearn.naive_bayes import GaussianNB
#       2 gnb = GaussianNB()
# ----> 3 gnb.fit(df, olddf.fund)
#       4 y_pred = gnb.predict(df)
#       5 print("Number of mislabeled points out of a total %d points : %d"
#
# C:\ProgramData\Anaconda2\lib\site-packages\sklearn\naive_bayes.py in fit(self, X, y, sample_weight)
#     180             Returns self.
#     181         """
# --> 182         X, y = check_X_y(X, y)
#     183         return self._partial_fit(X, y, np.unique(y), _refit=True,
#     184                                  sample_weight=sample_weight)
#
# ...

# %%
me=[1, 0,2, 0, 2.5,False, False,1]
gnb.predict([me])

# %%
gnb.predict_proba([me])

# %%
gnb.classes_
