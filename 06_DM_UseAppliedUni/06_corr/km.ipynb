# %%
import numpy as np
from pandas import Series, DataFrame
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import scale
import matplotlib.pylab as plt

# %%
olddf=pd.read_json('../01_Preprocessing//First.json').sort_index()

# %%
olddf.head(2)
# Out:
#           country  countryCoded     degree  degreeCoded       eng  engCoded  \
# 2  united kingdom             4  Doctorate            1      High         1
# 3   united states             0  Doctorate            1  VeryHigh         0
#
#    fieldGroup  fund  gpaBachelors  gpaMasters    gre highLevelBachUni  \
# 2           7  True           3.5    3.442986  False            False
# 3           5  True           2.5    3.500000   True             True
#
#   highLevelMasterUni  paper     targetUni  uniAccepted uniBachelors  \
# 2              False    6.0   heriot-watt          n/a         azad
# 3              False   10.5  northwestern  switzerland      mashhad
#
#        uniMasters   uniSelected  year
# 2             n/a   heriot-watt  2007
# 3  portland state  northwestern  2010

# %%
olddf.targetUni.replace('n/a',np.nan,inplace=True)

# %%
olddf.columns
# Out:
# Index([u'country', u'countryCoded', u'degree', u'degreeCoded', u'eng',
#        u'engCoded', u'fieldGroup', u'fund', u'gpaBachelors', u'gpaMasters',
#        u'gre', u'highLevelBachUni', u'highLevelMasterUni', u'paper',
#        u'targetUni', u'uniAccepted', u'uniBachelors', u'uniMasters',
#        u'uniSelected', u'year'],
#       dtype='object')

# %%
df=olddf[['countryCoded', 'degreeCoded','engCoded', 'fieldGroup', 'fund',
          'gpaBachelors', 'gpaMasters','gre', 'highLevelBachUni', 'highLevelMasterUni','paper','year']]

# %%
met=['pearson', 'kendall', 'spearman']
df.corr(method=met[0])
# Out:
#                     countryCoded  degreeCoded  engCoded  fieldGroup      fund  \
# countryCoded            1.000000    -0.233423  0.198801   -0.072802 -0.214348
# degreeCoded            -0.233423     1.000000 -0.180362    0.050019  0.507069
# engCoded                0.198801    -0.180362  1.000000   -0.024266 -0.240378
# fieldGroup             -0.072802     0.050019 -0.024266    1.000000  0.029535
# fund                   -0.214348     0.507069 -0.240378    0.029535  1.000000
# gpaBachelors           -0.071829     0.055572 -0.150995    0.030246  0.154465
# gpaMasters             -0.003735     0.034925 -0.062658    0.059075  0.060127
# gre                    -0.344367     0.277032 -0.280492    0.010689  0.300314
# highLevelBachUni       -0.141624     0.145979 -0.246722    0.020632  0.209722
# highLevelMasterUni     -0.184028     0.530627 -0.158683    0.043751  0.350306
# paper                  -0.059172     0.366760 -0.020208    0.025284  0.270571
# ...

# %%
# Canada, Masters, Medium Eng , Want Fund, 2.5GPA , 0GPA MS, NoGRE, NoTopUni,noTopUniMS, 1Paper, 2017
me=[1, 0, 2, 0, True, 2.5, 0, False, False, False, 1, 2017]
me=[4, 1, 1, 7, True, 3.5, 3.44299, False, False, False, 4, 2007]
sim=df.corrwith(Series(me), drop=True,axis=1).dropna()
sim
# Out:
# Series([], dtype: float64)
